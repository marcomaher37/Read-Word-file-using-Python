# %%
pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=872bcd5f52937bab33436b08ee05142408b053b2b862e5d80353511ce2c217d6
#   Stored in directory: /root/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# Successfully built docx2txt
# ...

# %%
import docx2txt
 
# read in word file
result = docx2txt.process("Test.docx")

# %%
# Print text on screen
print(result)
# Out:
# Welcome to java
#
# Today we will go to an introduction to java programming language
#
# We will start with the first program hello world program
#
# We use the print command to print the statement on screen
